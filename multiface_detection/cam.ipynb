# %%
from ultralytics import YOLO
import cv2

# Load the best model we have so far:
# model_file = "yolo11n.pt"
model_file = "best.pt"
model = YOLO(model_file)
# results = model.predict(source="0", show=True)
model.model.names = {0: 'maul', 1: 'mario', 2: 'gandhi'}

# %%
# Open camera and run real-time object detection using YOLO model
cap = cv2.VideoCapture(0)  # Use default camera (0)

while True:
    ret, frame = cap.read()  # Read a frame from camera
    if not ret:
        break
        
    # Run inference on frame
    results = model(frame)
    
    # Visualize results on frame
    annotated_frame = results[0].plot()
    
    # Display the frame
    cv2.imshow("YOLOv11 Detection", annotated_frame)
    
    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 207.7ms
# Speed: 57.0ms preprocess, 207.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 177.9ms
# Speed: 4.0ms preprocess, 177.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 156.8ms
# Speed: 4.2ms preprocess, 156.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 158.8ms
# Speed: 3.4ms preprocess, 158.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 157.3ms
# Speed: 3.7ms preprocess, 157.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 145.6ms
# Speed: 3.4ms preprocess, 145.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 151.4ms
# Speed: 3.1ms preprocess, 151.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
